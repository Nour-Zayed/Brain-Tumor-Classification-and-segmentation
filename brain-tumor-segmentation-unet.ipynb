# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import json
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import (
    Activation,
    Conv2D,
    Conv2DTranspose,
    MaxPooling2D,
    UpSampling2D,
    concatenate
)
from tensorflow.keras.optimizers import Adam
# Out:
# 2025-08-03 23:27:12.185320: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754263632.360260      20 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754263632.422311      20 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
DATA_DIR = '/kaggle/input/lgg-mri-segmentation/kaggle_3m'

# %%
import os
import shutil

DATA_DIR = '/kaggle/input/lgg-mri-segmentation/kaggle_3m'

images_dir = '/kaggle/working/images/'
masks_dir = '/kaggle/working/masks/'

os.makedirs(images_dir, exist_ok=True)
os.makedirs(masks_dir, exist_ok=True)

temp_images = []
temp_masks = []

for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        if file.endswith('.tif'):
            if 'mask' in file.lower():
                shutil.copy(os.path.join(root, file), os.path.join(masks_dir, file))
                temp_masks.append(file)
            else:
                shutil.copy(os.path.join(root, file), os.path.join(images_dir, file))
                temp_images.append(file)

final_images = []
final_masks = []

for img_file in sorted(temp_images):
    expected_mask = img_file.replace('.tif', '_mask.tif')
    if expected_mask in temp_masks:
        final_images.append(img_file)
        final_masks.append(expected_mask)

print(f"Total matched image-mask pairs: {len(final_images)}")
print(f"Total images copied: {len(temp_images)}")
print(f"Total masks copied: {len(temp_masks)}")
# Out:
# Total matched image-mask pairs: 3929
# Total images copied: 3929
# Total masks copied: 3929

# %%
def load_data(images_dir, masks_dir, img_size=256):
    images = []
    masks = []

    image_files = sorted(os.listdir(images_dir))
    mask_files = sorted(os.listdir(masks_dir))

    if len(image_files) != len(mask_files):
        print("⚠️ Warning: Number of images and masks do not match!")

    for img_file, mask_file in zip(image_files, mask_files):
        img_path = os.path.join(images_dir, img_file)
        mask_path = os.path.join(masks_dir, mask_file)

        # Load image
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        if img is None:
            print(f"[!] Image not loaded: {img_path}")
            continue
        img = cv2.resize(img, (img_size, img_size))
        img = img / 255.0  # Normalize

        # Load mask
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        if mask is None:
            print(f"[!] Mask not loaded: {mask_path}")
            continue
        mask = cv2.resize(mask, (img_size, img_size))
        mask = mask / 255.0

        # Skip empty masks (no tumor)
        if np.max(mask) == 0:
            print(f"[!] Skipping empty mask: {mask_file}")
            continue

        mask = np.expand_dims(mask, axis=-1)

        images.append(img)
        masks.append(mask)

    images = np.array(images, dtype=np.float32)
    masks = np.array(masks, dtype=np.float32)

    print(f"Loaded {len(images)} image-mask pairs with tumor.")
    return images, masks

# %% [markdown]
# ❗ We exclude empty masks (that contain no tumor)
# because training the model on them can lead to poor learning.
# The model may simply learn to always predict background (0),
# resulting in falsely high accuracy and low Dice score.

# %%
images_dir = '/kaggle/working/images'
masks_dir = '/kaggle/working/masks'

X, Y = load_data(images_dir, masks_dir)

print("Data loaded successfully.")
print(f"Images shape: {X.shape}")     # (num_samples, 256, 256, 3)
print(f"Masks shape:  {Y.shape}")     # (num_samples, 256, 256, 1)

if X.shape[0] != Y.shape[0]:
    print("⚠️ Warning: Number of images and masks do not match!")
else:
    print(f"🔢 Total image-mask pairs: {X.shape[0]}")
# Out:
# [!] Skipping empty mask: TCGA_CS_4941_19960909_10_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_19_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_21_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_22_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_23_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_4941_19960909_9_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_15_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_16_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_17_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_18_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_19_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_4942_19970222_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_10_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_11_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_4943_20000902_9_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_15_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_16_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_17_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_18_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_19_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_4944_20010208_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_13_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_14_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_15_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_16_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_17_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_18_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_19_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_5393_19990606_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_10_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_11_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_15_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_16_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_17_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_18_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_19_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_5395_19981004_9_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_10_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_11_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_23_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_24_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_5396_20010302_9_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_13_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_14_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_15_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_16_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_17_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_18_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_19_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_21_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_22_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_5397_20010315_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_10_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_11_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_12_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_13_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_14_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_21_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_22_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_23_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_24_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_25_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_6186_20000601_9_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_10_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_11_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_12_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_13_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_18_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_19_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_21_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_22_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_23_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_24_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_6188_20010812_9_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_12_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_13_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_14_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_15_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_16_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_17_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_18_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_19_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_6290_20000917_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_21_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_22_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_23_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_24_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_6665_20010817_9_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_10_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_11_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_12_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_24_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_25_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_26_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_6666_20011109_9_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_18_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_19_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_6667_20011105_9_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_10_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_11_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_12_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_13_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_14_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_22_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_23_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_24_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_25_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_26_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_27_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_28_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_6668_20011025_9_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_1_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_20_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_21_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_22_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_2_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_3_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_4_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_5_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_6_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_7_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_8_mask.tif
# [!] Skipping empty mask: TCGA_CS_6669_20020102_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_32_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_33_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_37_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_38_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_5849_19950405_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_25_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_26_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_27_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_28_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_29_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_30_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_31_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_32_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_33_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_37_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_38_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_39_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_40_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_5851_19950428_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_20_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_21_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_22_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_23_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_24_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_25_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_26_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_27_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_28_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_29_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_30_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_31_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_32_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_33_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_5852_19950709_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_19_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_20_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_21_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_22_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_23_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_24_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_32_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_33_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_5853_19950823_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_19_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_20_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_21_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_32_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_33_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_5854_19951104_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_25_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_26_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_5855_19951217_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_32_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_33_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_5871_19941206_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_19_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_20_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_21_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_22_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_23_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_24_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_25_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_26_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_27_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_28_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_29_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_30_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_31_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_53_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_54_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_55_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_56_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_57_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_58_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_59_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_60_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_61_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_62_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_63_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_64_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_65_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_66_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_67_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_68_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_69_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_70_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_71_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_5872_19950223_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_19_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_28_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_29_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_30_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_31_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_32_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_33_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_37_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_38_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_5874_19950510_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_32_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_33_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_37_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_38_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_39_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_40_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_41_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_42_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_43_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_44_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_45_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_46_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_47_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_48_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_49_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_50_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_51_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_52_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_53_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_6399_19830416_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_37_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_38_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_39_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_40_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_41_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_42_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_43_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_44_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_45_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_46_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_47_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_48_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_49_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_50_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_51_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_52_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_53_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_54_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_55_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_56_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_57_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_6400_19830518_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_44_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_45_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_46_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_47_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_48_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_49_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_50_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_51_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_6401_19831001_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_19_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_20_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_21_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_22_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_23_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_24_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_25_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_26_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_27_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_28_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_45_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_46_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_47_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_48_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_49_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_50_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_51_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_52_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_53_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_6404_19850629_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_19_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_20_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_21_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_22_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_23_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_24_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_25_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_26_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_27_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_28_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_29_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_30_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_31_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_32_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_33_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_37_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_38_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_39_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_40_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_41_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_51_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_52_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_53_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_54_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_55_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_56_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_57_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_58_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_59_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_60_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_6405_19851005_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_37_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_38_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_39_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_40_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_41_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_42_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_43_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_44_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_45_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_46_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_47_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_48_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_49_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_50_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_51_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_52_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_53_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_54_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_55_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_56_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_57_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_58_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_6407_19860514_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_19_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_20_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_48_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_49_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_50_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_51_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_52_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_53_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_54_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_55_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_56_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_6408_19860521_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_40_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_41_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_42_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_43_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_44_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_45_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_46_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_47_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_48_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_49_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_50_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_51_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_52_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_7008_19830723_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_17_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_18_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_19_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_20_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_21_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_22_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_23_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_3_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_4_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_51_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_52_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_53_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_54_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_55_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_56_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_57_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_58_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_5_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_6_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_7_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_8_mask.tif
# [!] Skipping empty mask: TCGA_DU_7010_19860307_9_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_10_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_11_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_12_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_13_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_14_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_15_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_16_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_1_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_29_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_2_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_30_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_31_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_32_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_33_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_34_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_35_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_36_mask.tif
# [!] Skipping empty mask: TCGA_DU_7013_19860523_37_mask.tif
# ...
# [!] Skipping empty mask: TCGA_HT_7882_19970125_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_7882_19970125_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_7882_19970125_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_7882_19970125_8_mask.tif
# [!] Skipping empty mask: TCGA_HT_7882_19970125_9_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_13_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_14_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_15_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_16_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_17_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_18_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_19_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_20_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_7884_19980913_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_12_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_13_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_14_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_15_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_16_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_17_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_18_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_19_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_20_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_8018_19970411_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_10_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_11_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_12_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_13_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_31_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_32_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_8_mask.tif
# [!] Skipping empty mask: TCGA_HT_8105_19980826_9_mask.tif
# [!] Skipping empty mask: TCGA_HT_8106_19970727_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_8106_19970727_21_mask.tif
# [!] Skipping empty mask: TCGA_HT_8106_19970727_22_mask.tif
# [!] Skipping empty mask: TCGA_HT_8106_19970727_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_8106_19970727_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_8106_19970727_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_8106_19970727_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_8106_19970727_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_8106_19970727_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_15_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_16_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_17_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_18_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_19_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_20_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_8107_19980708_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_10_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_11_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_12_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_13_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_21_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_22_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_8_mask.tif
# [!] Skipping empty mask: TCGA_HT_8111_19980330_9_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_10_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_11_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_21_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_8_mask.tif
# [!] Skipping empty mask: TCGA_HT_8113_19930809_9_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_21_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_22_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_8_mask.tif
# [!] Skipping empty mask: TCGA_HT_8114_19981030_9_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_17_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_18_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_19_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_20_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_21_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_22_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_23_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_8563_19981209_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_10_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_11_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_12_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_13_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_14_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_30_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_31_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_32_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_8_mask.tif
# [!] Skipping empty mask: TCGA_HT_A5RC_19990831_9_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_10_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_11_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_23_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_24_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_25_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_26_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_27_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_28_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_8_mask.tif
# [!] Skipping empty mask: TCGA_HT_A616_19991226_9_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_10_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_11_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_12_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_13_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_14_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_15_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_16_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_17_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_18_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_19_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_20_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_21_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_59_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_60_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_61_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_62_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_63_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_64_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_65_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_66_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_67_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_68_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_69_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_70_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_71_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_72_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_73_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_74_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_75_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_76_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_77_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_78_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_79_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_80_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_81_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_82_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_83_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_84_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_85_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_86_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_87_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_88_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_8_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61A_20000127_9_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_10_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_11_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_12_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_13_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_14_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_15_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_16_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_17_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_18_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_19_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_1_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_20_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_21_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_22_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_23_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_24_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_2_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_3_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_4_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_50_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_51_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_52_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_53_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_54_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_55_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_56_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_57_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_58_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_59_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_5_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_60_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_61_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_62_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_63_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_64_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_65_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_66_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_67_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_68_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_69_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_6_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_70_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_71_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_72_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_73_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_74_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_75_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_76_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_77_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_78_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_79_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_7_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_80_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_81_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_82_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_83_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_84_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_85_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_86_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_87_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_88_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_8_mask.tif
# [!] Skipping empty mask: TCGA_HT_A61B_19991127_9_mask.tif
# Loaded 1373 image-mask pairs with tumor.
# Data loaded successfully.
# Images shape: (1373, 256, 256, 3)
# Masks shape:  (1373, 256, 256, 1)
# 🔢 Total image-mask pairs: 1373

# %%
index = 100
sample_image = X[index]
sample_mask = Y[index]

pred_mask = model.predict(np.expand_dims(sample_image, axis=0), verbose=0)[0]

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(sample_image)
plt.title("Original MRI")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(sample_mask.squeeze(), cmap='gray')
plt.title("Ground Truth Mask")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(pred_mask.squeeze(), cmap='gray')
plt.title("Predicted Mask (Raw Output)")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20/745760972.py in <cell line: 0>()
#       3 sample_mask = Y[index]
#       4
# ----> 5 pred_mask = model.predict(np.expand_dims(sample_image, axis=0), verbose=0)[0]
#       6
#       7 plt.figure(figsize=(15, 5))
#
# NameError: name 'model' is not defined

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.imshow(X[idx])
plt.title("MRI Image")

plt.subplot(1,2,2)
plt.imshow(Y[idx].squeeze(), cmap='gray')
plt.title("Mask")

plt.show()

# %% [markdown]
# ### 🧠 Visualize Overlay of Image and Segmentation Mask (Ground Truth)

# %%
def visualize_full_comparison(model, image, true_mask, index=None):
    import matplotlib.pyplot as plt
    import numpy as np
    import cv2

    pred_mask = model.predict(np.expand_dims(image, axis=0), verbose=0)[0]
    pred_mask_bin = (pred_mask > 0.5).astype(np.float32)

    image_uint8 = (image * 255).astype(np.uint8)
    
    def create_overlay(img, mask, color=(255, 0, 0)):
        mask = mask.squeeze()
        mask_rgb = np.zeros_like(img)
        mask_rgb[:, :, 0] = (mask * 255).astype(np.uint8)  # Red channel
        return cv2.addWeighted(img, 0.7, mask_rgb, 0.3, 0)

    overlay_gt = create_overlay(image_uint8, true_mask)
    overlay_pred = create_overlay(image_uint8, pred_mask_bin)

    plt.figure(figsize=(20, 8))

    plt.subplot(1, 5, 1)
    plt.imshow(image)
    plt.title("🧠 Original MRI")
    plt.axis('off')

    plt.subplot(1, 5, 2)
    plt.imshow(true_mask.squeeze(), cmap='gray')
    plt.title("🎯 Ground Truth Mask")
    plt.axis('off')

    plt.subplot(1, 5, 3)
    plt.imshow(pred_mask.squeeze(), cmap='gray')
    plt.title("🔮 Predicted Mask (Raw)")
    plt.axis('off')

    plt.subplot(1, 5, 4)
    plt.imshow(overlay_gt)
    plt.title("📌 Overlay with GT")
    plt.axis('off')

    plt.subplot(1, 5, 5)
    plt.imshow(overlay_pred)
    plt.title("📌 Overlay with Prediction")
    plt.axis('off')

    plt.tight_layout()
    if index is not None:
        plt.suptitle(f"Sample Index: {index}", fontsize=16, y=1.05)
    plt.show()

idx = 100
visualize_full_comparison(model, X[idx], Y[idx], index=idx)

# %%
def visualize_full_comparison(model, image, true_mask, index=None):
    import matplotlib.pyplot as plt
    import numpy as np
    import cv2

    pred_mask = model.predict(np.expand_dims(image, axis=0), verbose=0)[0]
    pred_mask_bin = (pred_mask > 0.5).astype(np.float32)

    image_uint8 = (image * 255).astype(np.uint8)
    
    def create_overlay(img, mask, color=(255, 0, 0)):
        mask = mask.squeeze()
        mask_rgb = np.zeros_like(img)
        mask_rgb[:, :, 0] = (mask * 255).astype(np.uint8)  # Red channel
        return cv2.addWeighted(img, 0.7, mask_rgb, 0.3, 0)

    overlay_gt = create_overlay(image_uint8, true_mask)
    overlay_pred = create_overlay(image_uint8, pred_mask_bin)

    plt.figure(figsize=(20, 8))

    plt.subplot(1, 5, 1)
    plt.imshow(image)
    plt.title("Original MRI")
    plt.axis('off')

    plt.subplot(1, 5, 2)
    plt.imshow(true_mask.squeeze(), cmap='gray')
    plt.title("Ground Truth Mask")
    plt.axis('off')

    plt.subplot(1, 5, 3)
    plt.imshow(pred_mask.squeeze(), cmap='gray')
    plt.title("Predicted Mask (Raw)")
    plt.axis('off')

    plt.subplot(1, 5, 4)
    plt.imshow(overlay_gt)
    plt.title("Overlay with GT")
    plt.axis('off')

    plt.subplot(1, 5, 5)
    plt.imshow(overlay_pred)
    plt.title(" Overlay with Prediction")
    plt.axis('off')

    plt.tight_layout()
    if index is not None:
        plt.suptitle(f"Sample Index: {index}", fontsize=16, y=1.05)
    plt.show()

idx = 100
visualize_full_comparison(model, X[idx], Y[idx], index=idx)

# %%
fig, ax = plt.subplots(3, 6, figsize=(16, 9))
fig.suptitle('MRI vs Ground Truth vs Prediction', fontsize=18)

for i in range(6):
    n = np.random.randint(len(X))  # Random sample index

    image = X[n]
    gt_mask = Y[n]
    pred_mask = model.predict(np.expand_dims(image, axis=0), verbose=0)[0]
    pred_mask_bin = (pred_mask > 0.5).astype(np.float32)

    # Row 0 - Original Image
    ax[0][i].imshow(image)
    ax[0][i].set_xticks([])
    ax[0][i].set_yticks([])
    if i == 0:
        ax[0][i].set_ylabel('MRI', fontsize=14)

    # Row 1 - Ground Truth
    ax[1][i].imshow(gt_mask.squeeze(), cmap='gray')
    ax[1][i].set_xticks([])
    ax[1][i].set_yticks([])
    if i == 0:
        ax[1][i].set_ylabel('Ground Truth', fontsize=14)

    # Row 2 - Prediction
    ax[2][i].imshow(pred_mask_bin.squeeze(), cmap='gray')
    ax[2][i].set_xticks([])
    ax[2][i].set_yticks([])
    if i == 0:
        ax[2][i].set_ylabel('Prediction', fontsize=14)

plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, Dropout, BatchNormalization

# Input
inputs = Input((256, 256, 3))

# Encoder
c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
c1 = BatchNormalization()(c1)
c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
c1 = BatchNormalization()(c1)
c1 = Dropout(0.1)(c1)
p1 = MaxPooling2D((2, 2))(c1)

c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
c2 = BatchNormalization()(c2)
c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
c2 = BatchNormalization()(c2)
c2 = Dropout(0.1)(c2)
p2 = MaxPooling2D((2, 2))(c2)

c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
c3 = BatchNormalization()(c3)
c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
c3 = BatchNormalization()(c3)
c3 = Dropout(0.2)(c3)
p3 = MaxPooling2D((2, 2))(c3)

c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
c4 = BatchNormalization()(c4)
c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
c4 = BatchNormalization()(c4)
c4 = Dropout(0.3)(c4)
p4 = MaxPooling2D((2, 2))(c4)

# Bottleneck
c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
c5 = BatchNormalization()(c5)
c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)
c5 = BatchNormalization()(c5)
c5 = Dropout(0.4)(c5)

# Decoder
u6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
c6 = BatchNormalization()(c6)
c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(c6)
c6 = BatchNormalization()(c6)
c6 = Dropout(0.3)(c6)

u7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
c7 = BatchNormalization()(c7)
c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(c7)
c7 = BatchNormalization()(c7)
c7 = Dropout(0.2)(c7)

u8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
c8 = BatchNormalization()(c8)
c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(c8)
c8 = BatchNormalization()(c8)
c8 = Dropout(0.1)(c8)

u9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = concatenate([u9, c1])
c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
c9 = BatchNormalization()(c9)
c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(c9)
c9 = BatchNormalization()(c9)
c9 = Dropout(0.1)(c9)

# Output
outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

# %% [markdown]
# ## 🔷 Define The Model

# %%
from tensorflow.keras.models import Model

model = Model(inputs=[inputs], outputs=[outputs])
model.summary()

# %% [markdown]
# ## 🔷 Compile the U-Net Model

# %%
from tensorflow.keras.optimizers import Adam

# Compile Model

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 🔷 Prepare Data Generator / Splitting Data (Train & Validation)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=42)

print(f"Training Data: {X_train.shape}, {Y_train.shape}")
print(f"Validation Data: {X_val.shape}, {Y_val.shape}")

# %% [markdown]
# ## 🔷 Train the Model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, verbose=1)

# Train
history = model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=40,  
    batch_size=8,
    callbacks=[early_stop, reduce_lr, checkpoint]
)

# %% [markdown]
# ## 🔷 Plot Training & Validation Accuracy/Loss Curves

# %%
# Accuracy
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', marker='o')
plt.title('📈 Accuracy Over Epochs', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Loss
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('📉 Loss Over Epochs', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🔷 Test Prediction on a Sample Image

# %%
# Predict on validation sample
sample_img = X_val[0]
sample_mask = Y_val[0]

pred_mask = model.predict(sample_img[np.newaxis, ...])[0]

plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.imshow(sample_img)
plt.title('Original Image')

plt.subplot(1, 3, 2)
plt.imshow(sample_mask.squeeze(), cmap='gray')
plt.title('Ground Truth Mask')

plt.subplot(1, 3, 3)
plt.imshow(pred_mask.squeeze(), cmap='viridis')
plt.title('Predicted Mask')
plt.colorbar()  # Optional

plt.show()

# %% [markdown]
# ## 🔷 Define Dice Coefficient Metric

# %%
import tensorflow.keras.backend as K
import tensorflow as tf

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1 - dice_coefficient(y_true, y_pred, smooth)

# 🔹 3. Combined BCE + Dice loss
def combined_bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    dl = dice_loss(y_true, y_pred)
    return bce + dl

# %% [markdown]
# ## 🔷 Compile the Model Again with Dice Metric

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_bce_dice_loss,
    metrics=[dice_coefficient, 'accuracy']
)

# %% [markdown]
# ## 🔷 Evaluate Model on Validation Data

# %%
results = model.evaluate(X_val, Y_val)
print(f"Validation Loss: {results[0]}")
print(f"Validation Dice Coefficient: {results[2]}")

# %% [markdown]
# ⚠️ Note: We rely on Dice Coefficient rather than accuracy because it's a much better metric for medical image segmentation.
#
#  In such tasks, the lesion/tumor regions are small compared to the background, so pixel-wise accuracy can be misleading.
#
#  A high Dice Score (e.g. 0.98) indicates excellent overlap between predicted and true masks, even if accuracy appears lower.

# %% [markdown]
# ## 🔷 Predict & Visualize Result

# %%
# Predict a sample image
sample_img = X_val[0]
sample_mask = Y_val[0]

# Predict mask (without thresholding)
pred_mask = model.predict(sample_img[np.newaxis, ...])[0]

# Plot Original Image, Ground Truth, Predicted Mask (as probabilities)
plt.figure(figsize=(12,6))

plt.subplot(1,3,1)
plt.imshow(sample_img)
plt.title("Original Image")

plt.subplot(1,3,2)
plt.imshow(sample_mask.squeeze(), cmap='gray')
plt.title("Ground Truth Mask")

plt.subplot(1,3,3)
plt.imshow(pred_mask.squeeze(), cmap='jet')  # Using 'jet' to visualize probabilities
plt.title("Predicted Mask (Probabilities)")

plt.show()

# %% [markdown]
# ## 🔷 Save Model

# %%
model.save('best_model.h5')

# %%
import matplotlib.pyplot as plt
import random
import numpy as np

num_samples = 5
random_indices = random.sample(range(len(X)), num_samples)

plt.figure(figsize=(15, num_samples * 3))

for i, idx in enumerate(random_indices):
    image = X[idx]
    mask = Y[idx]

    pred_mask = model.predict(np.expand_dims(image, axis=0))[0]
    pred_mask_bin = (pred_mask > 0.5).astype(np.float32)

    # Row for each sample
    plt.subplot(num_samples, 3, i*3 + 1)
    plt.imshow(image)
    plt.title(f"Original Image #{idx}")
    plt.axis('off')

    plt.subplot(num_samples, 3, i*3 + 2)
    plt.imshow(mask.squeeze(), cmap='gray')
    plt.title("Ground Truth Mask")
    plt.axis('off')

    plt.subplot(num_samples, 3, i*3 + 3)
    plt.imshow(pred_mask_bin.squeeze(), cmap='gray')
    plt.title("Predicted Mask")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

# Load custom model with all required custom loss/metrics
model = load_model(
    'best_model.h5',
    custom_objects={
        'dice_coefficient': dice_coefficient,
        'dice_loss': dice_loss,
        'combined_bce_dice_loss': combined_bce_dice_loss
    }
)

print(" Model loaded successfully!")
